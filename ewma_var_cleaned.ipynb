# %% [markdown]
# #Project Title:
# #EWMA (Exponentially Weighted Moving Average) Variance Tracker: Real-Time Predictive Modeling and Automated Core-Tail Gaussian Mixtures for CrunchDAO.

# %% [markdown]
# #Project Overview and Objectives: CrunchDAO Market Competition
#
# 1.Designed for Adaptive Signal Modeling in CrunchDAO’s Financial Forecasting Challenge
#
# 2.Built to Enhance Uncertainty Estimation in CrunchDAO’s Market Prediction Framework
#
# 3.Optimized for Real-Time Variance Tracking in CrunchDAO Competitive Modeling
#
# 4.A Core-Tail Gaussian Approach for CrunchDAO’s Volatility-Sensitive Forecasting Tasks
#
# 5.Contributing to CrunchDAO’s Quantitative Research with Threat-Aware Variance Estimation

# %%
# @crunch/keep:on
import os
os.environ['SCIPY_ARRAY_API'] = '1'

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Requirements
# !pip install birdgame river --upgrade
# Out:
# Collecting birdgame
#   Downloading birdgame-0.3.1-py3-none-any.whl.metadata (9.1 kB)
# Collecting river
#   Downloading river-0.22.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from birdgame) (2.2.2)
# Collecting density (from birdgame)
#   Downloading density-1.0.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting densitypdf>=0.1.4 (from birdgame)
#   Downloading densitypdf-0.1.4-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from birdgame) (3.10.0)
# Collecting redis (from birdgame)
#   Downloading redis-7.0.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: orjson in /usr/local/lib/python3.12/dist-packages (from birdgame) (3.11.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from birdgame) (4.67.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from birdgame) (2.0.2)
# Requirement already satisfied: IPython in /usr/local/lib/python3.12/dist-packages (from birdgame) (7.34.0)
# Collecting pandas (from birdgame)
#   Downloading pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: scipy<2.0.0,>=1.14.1 in /usr/local/lib/python3.12/dist-packages (from river) (1.16.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->birdgame) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->birdgame) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->birdgame) (2025.2)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.12/dist-packages (from density->birdgame) (2.11.10)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from IPython->birdgame) (75.2.0)
# Collecting jedi>=0.16 (from IPython->birdgame)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from IPython->birdgame) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from IPython->birdgame) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.12/dist-packages (from IPython->birdgame) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from IPython->birdgame) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from IPython->birdgame) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from IPython->birdgame) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from IPython->birdgame) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from IPython->birdgame) (4.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->birdgame) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->birdgame) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->birdgame) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->birdgame) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->birdgame) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->birdgame) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->birdgame) (3.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->IPython->birdgame) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->IPython->birdgame) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->birdgame) (0.2.14)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->birdgame) (1.17.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->density->birdgame) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic->density->birdgame) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.12/dist-packages (from pydantic->density->birdgame) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->density->birdgame) (0.4.2)
# Downloading birdgame-0.3.1-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.2/59.2 kB 4.8 MB/s eta 0:00:00
# Downloading river-0.22.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 56.1 MB/s eta 0:00:00
# Downloading densitypdf-0.1.4-py3-none-any.whl (8.3 kB)
# Downloading pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 100.3 MB/s eta 0:00:00
# Downloading density-1.0.1-py3-none-any.whl (3.8 kB)
# Downloading redis-7.0.1-py3-none-any.whl (339 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 339.9/339.9 kB 28.0 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 69.9 MB/s eta 0:00:00
# Installing collected packages: redis, jedi, pandas, densitypdf, river, density, birdgame
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
# Successfully installed birdgame-0.3.1 density-1.0.1 densitypdf-0.1.4 jedi-0.19.2 pandas-2.3.3 redis-7.0.1 river-0.22.0

# %%
# Standard library imports
import os
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import time
from tqdm.auto import tqdm

# Birdgame package imports
from birdgame.trackers.trackerbase import TrackerBase
from birdgame import HORIZON
from birdgame.visualization.viz_fewvar import visualize_fewvar

# %% [markdown]
# ### Warm up example: FEWVar model

# %%
# Visualize FEWVar on synthetic data with different fading_factor values
list_fading_factor = [0.1, 0.01, 0.0001]
for factor in list_fading_factor:
    visualize_fewvar(fading_factor=factor, list_variances=[1, 5, 2, 8])

# %%
import math
import numpy as np
from birdgame.stats.fewvar import FEWVar


class EMWAVarTracker(TrackerBase):
    """
    A model that fits a mixture of two Gaussian distributions, one capturing the core
    distribution and another with a larger variance to capture the tails.
    Using EWMA variance

    Parameters
    ----------
    fading_factor : float
        Parameter controlling how quickly older data is de-emphasized in variance estimation.
    horizon : int
        The prediction horizon in seconds (how far into the future predictions should be made).
    warmup : int
        The number of ticks taken to warm up the model (wealth does not change during this period).
    """

    def __init__(self, horizon=HORIZON):
        super().__init__(horizon)
        self.fading_factor = Constants.FADE_FACTOR
        self.current_x = None
        self.ewa_dx_core = FEWVar(fading_factor=self.fading_factor)
        self.ewa_dx_tail = FEWVar(fading_factor=self.fading_factor)
        self.weights = [0.95, 0.05]  # Heavily weight the core distribution

        self.latest_threat = 0.0

        self.warmup_cutoff = Constants.WARMUP_CUTOFF
        self.tick_count = 0

    def tick(self, payload, performance_metrics):
        """
        Ingest a new record (payload), store it internally and update the
        estimated Gaussian mixture model.

        The core distribution captures regular variance, while the tail distribution
        captures extreme deviations.

        Function signature can also look like tick(self, payload) since performance_metrics
        is an optional parameter.

        Parameters
        ----------
        payload : dict
            Must contain 'time' (int/float) and 'dove_location' (float).
        performance_metrics : dict (is optional)
            Dict containing 'wealth', 'likelihood_ewa', 'recent_likelihood_ewa'
        """

        # # To see the performance metrics on each tick
        # print(f"performance_metrics: {performance_metrics}")

        # # Can trigger a warmup by checking if a performance metric drops below a threshold
        # if performance_metrics['recent_likelihood_ewa'] < 1.1:
        #     self.tick_count = 0

        x = payload['dove_location']
        t = payload['time']
        # falcon_x = payload["falcon_location"]
        # wingspan = payload["falcon_wingspan"]
        self.add_to_quarantine(t, x)
        self.current_x = x
        prev_x = self.pop_from_quarantine(t)

        if prev_x is not None:
            x_change = x - prev_x

            # Winsorize the update for the core estimator to avoid tail effects
            threshold = 2.0 * math.sqrt(self.ewa_dx_core.get() if self.count > 0 else 1.0)
            if threshold > 0:
                winsorized_x_change = np.clip(x_change, -threshold, threshold)
            else:
                winsorized_x_change = x_change
            self.ewa_dx_core.update(winsorized_x_change)

            # Feed the tail estimator with double the real change magnitude
            self.ewa_dx_tail.update(2.0 * x_change)

            self.count += 1

        # # Update threat level: high wingspan + low distance => higher uncertainty
        # dist = abs(falcon_x - x)
        # self.latest_threat = wingspan / (dist + 1e-3)  # Avoid divide-by-zero

        self.tick_count += 1

    def predict(self):
        """
        Return a dictionary representing the best guess of the distribution,
        modeled as a mixture of two Gaussians.

        If the model is in the warmup period, return None.
        """
        # Check if the model is warming up
        if self.tick_count < self.warmup_cutoff or self.current_x is None:
            return None

        # the central value (mean) of the gaussian distribution will be represented by the current value
        x_mean = self.current_x
        components = []

        for i, ewa_dx in enumerate([self.ewa_dx_core, self.ewa_dx_tail]):
            try:
                x_var = ewa_dx.get()
                x_std = math.sqrt(x_var)
            except:
                x_std = 1.0

            if x_std <= 1e-6:
                x_std = 1e-6

            # std = max(std, 1e-6)  # Avoid degenerate std

            # # Scale std based on current threat level (tunable factor 0.2)
            # scaled_std = std * (1.0 + 0.2 * self.latest_threat)

            components.append({
                "density": {
                    "type": "builtin",
                    "name": "norm",
                    "params": {"loc": x_mean, "scale": x_std}
                },
                "weight": self.weights[i]
            })

        prediction_density = {
            "type": "mixture",
            "components": components
        }

        return prediction_density

# %%
import math
import numpy as np
from birdgame.stats.fewvar import FEWVar

class EMWAVarTracker(TrackerBase):
    """
    A model that fits a mixture of two Gaussian distributions, one capturing the core
    distribution and another with a larger variance to capture the tails.
    Using EWMA variance with threat scaling and dynamic tail weighting.
    """

    def __init__(self, horizon=HORIZON):
        super().__init__(horizon)
        self.fading_factor = Constants.FADE_FACTOR
        self.current_x = None
        self.ewa_dx_core = FEWVar(fading_factor=self.fading_factor)
        self.ewa_dx_tail = FEWVar(fading_factor=self.fading_factor)
        self.weights = [0.95, 0.05]  # Initial weights

        self.latest_threat = 0.0
        self.warmup_cutoff = Constants.WARMUP_CUTOFF
        self.tick_count = 0

    def tick(self, payload, performance_metrics=None):
        x = payload['dove_location']
        t = payload['time']
        falcon_x = payload.get("falcon_location")
        wingspan = payload.get("falcon_wingspan")

        self.add_to_quarantine(t, x)
        self.current_x = x
        prev_x = self.pop_from_quarantine(t)

        if prev_x is not None:
            x_change = x - prev_x

            # Winsorize core update
            threshold = 2.0 * math.sqrt(self.ewa_dx_core.get() if self.count > 0 else 1.0)
            winsorized_x_change = np.clip(x_change, -threshold, threshold) if threshold > 0 else x_change
            self.ewa_dx_core.update(winsorized_x_change)

            # Tail update with amplified change
            self.ewa_dx_tail.update(2.0 * x_change)
            self.count += 1

        # Update threat level if falcon data is available
        if falcon_x is not None and wingspan is not None:
            dist = abs(falcon_x - x)
            raw_threat = wingspan / (dist + 1e-3)
            self.latest_threat = 0.9 * self.latest_threat + 0.1 * raw_threat  # EWMA smoothing

        # Optional: adapt weights based on volatility ratio
        vol_ratio = self.ewa_dx_tail.get() / (self.ewa_dx_core.get() + 1e-6)
        tail_weight = min(0.5, max(0.05, 0.05 * vol_ratio))
        self.weights = [1.0 - tail_weight, tail_weight]

        # Optional: performance-based adaptation
        if performance_metrics and performance_metrics.get("recent_likelihood_ewa", 2.0) < 1.1:
            self.weights = [0.85, 0.15]  # temporarily boost tail weight

        self.tick_count += 1

    def predict(self):
        if self.tick_count < self.warmup_cutoff or self.current_x is None:
            return None

        x_mean = self.current_x
        components = []

        for i, ewa_dx in enumerate([self.ewa_dx_core, self.ewa_dx_tail]):
            try:
                x_var = ewa_dx.get()
                x_std = math.sqrt(x_var)
            except:
                x_std = 1.0

            x_std = max(x_std, 1e-6)

            # Threat-scaled std
            scaled_std = x_std * (1.0 + 0.2 * self.latest_threat)

            components.append({
                "density": {
                    "type": "builtin",
                    "name": "norm",
                    "params": {"loc": x_mean, "scale": scaled_std}
                },
                "weight": self.weights[i]
            })

        return {
            "type": "mixture",
            "components": components
        }

# %%
# Parameters
class Constants:
    FADE_FACTOR = 0.0001
    WARMUP_CUTOFF = 0

# %% [markdown]
# ### Run on a remote static data file

# %%
# Initialize Tracker
tracker = EMWAVarTracker()

# Run on remote data
tracker.test_run(live=False)
# Out:
# 0it [00:00, ?it/s]
# My log-likelihood score: -9.8950 VS Benchmark log-likelihood score: -11.0849
#      .... and mine is better. Ratio is 0.89265
# My log-likelihood score: -4.0967 VS Benchmark log-likelihood score: -3.3915
#      .... and mine is worse. Ratio is 1.20794
# My log-likelihood score: -2.7220 VS Benchmark log-likelihood score: -2.8604
#      .... and mine is better. Ratio is 0.95162
# My log-likelihood score: -2.1972 VS Benchmark log-likelihood score: -2.2542
#      .... and mine is better. Ratio is 0.97471
# My log-likelihood score: -1.9212 VS Benchmark log-likelihood score: -1.7795
#      .... and mine is worse. Ratio is 1.07964
# My log-likelihood score: -1.7833 VS Benchmark log-likelihood score: -1.4862
#      .... and mine is worse. Ratio is 1.19988
# My log-likelihood score: -1.7132 VS Benchmark log-likelihood score: -1.2124
#      .... and mine is worse. Ratio is 1.41309
# My log-likelihood score: -1.6501 VS Benchmark log-likelihood score: -0.9781
#      .... and mine is worse. Ratio is 1.68699
# My log-likelihood score: -1.6084 VS Benchmark log-likelihood score: -0.7381
#      .... and mine is worse. Ratio is 2.17917
# My log-likelihood score: -1.5598 VS Benchmark log-likelihood score: -0.5376
#      .... and mine is worse. Ratio is 2.90123
# My log-likelihood score: -1.5051 VS Benchmark log-likelihood score: -0.4380
#      .... and mine is worse. Ratio is 3.43662
# My log-likelihood score: -1.4677 VS Benchmark log-likelihood score: -0.3514
#      .... and mine is worse. Ratio is 4.17669
# My log-likelihood score: -1.4366 VS Benchmark log-likelihood score: -0.2351
#      .... and mine is worse. Ratio is 6.10939
# Interrupted

# %% [markdown]
# ### Run on live data

# %%
# Initialize Tracker
tracker = EMWAVarTracker()

# Run on live data
tracker.test_run(live=True)
# Interrupt cell to stop run
# Out:
# 0it [00:00, ?it/s]
# My log-likelihood score: -1.0508 VS Benchmark log-likelihood score: -0.9657
#      .... and mine is worse. Ratio is 1.08821
# Interrupted

# %% [markdown]
# ### An animated run

# %%
# %matplotlib inline
from IPython.display import HTML

tracker = EMWAVarTracker()

animated = tracker.test_run_animated(live=False, from_notebook=True)

# Display animation in notebook
HTML(animated.to_jshtml())
# Interrupt cell to stop run
# Out:
# 0it [00:00, ?it/s]
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# No scores to average
# No recent scores available.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2743959459.py in <cell line: 0>()
#       4 tracker = EMWAVarTracker()
#       5
# ----> 6 animated = tracker.test_run_animated(live=False, from_notebook=True)
#       7
#       8 # Display animation in notebook
#
# /usr/local/lib/python3.12/dist-packages/birdgame/trackers/trackerbase.py in test_run_animated(self, live, n_data_points, recent_score_window_size, interval_animation, from_notebook, max_rows)
#     130
#     131         use_plt_show = True if not from_notebook else False
# --> 132         animated = animated_predictions_graph(gen, my_run, bmark_run, n_data_points=n_data_points,
#     133                                               interval_animation=interval_animation, use_plt_show=use_plt_show)
#     134
#
# /usr/local/lib/python3.12/dist-packages/birdgame/visualization/animated_viz_predictions.py in animated_predictions_graph(gen, my_run, bmark_run, n_data_points, interval_animation, use_plt_show)
#     184             yield None
#     185
# --> 186     animate(
#     187         infinite(),
#     188         update,
#
# /usr/local/lib/python3.12/dist-packages/birdgame/visualization/animator.py in animate(iterator, animate, interval, environment)
#     114                     continue
#     115
# --> 116                 functions.show(figure)
#     117
#     118                 plt.pause(interval)
#
# /usr/local/lib/python3.12/dist-packages/birdgame/visualization/animator.py in show(self, figure)
#      32
#      33     def show(self, figure):
# ---> 34         self._display(figure)
#      35
#      36         self._javascript("""
#
# /usr/local/lib/python3.12/dist-packages/birdgame/visualization/animator.py in _display(self, figure)
#      20     def _display(self, figure):
#      21         from IPython.display import display
# ---> 22         display(figure)
#      23
#      24
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     318             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     319         else:
# --> 320             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     321             if not format_dict:
#     322                 # nothing to display (e.g. _ipython_display_ took over)
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-2> in __call__(self, obj)
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2182                 # force the figure dpi to 72), so we need to set it again here.
#    2183                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2184                     result = print_method(
#    2185                         filename,
#    2186                         facecolor=facecolor,
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/backend_bases.py in <lambda>(*args, **kwargs)
#    2038                 "bbox_inches_restore"}
#    2039             skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2040             print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2041                 *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2042         else:  # Let third-parties do as they see fit.
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs)
#     479             *metadata*, including the default 'Software' key.
#     480         """
# --> 481         self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#     482
#     483     def print_to_buffer(self):
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/backends/backend_agg.py in _print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     427         *pil_kwargs* and *metadata* are forwarded).
#     428         """
# --> 429         FigureCanvasAgg.draw(self)
#     430         mpl.image.imsave(
#     431             filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/backends/backend_agg.py in draw(self)
#     380         with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     381               else nullcontext()):
# --> 382             self.figure.draw(self.renderer)
#     383             # A GUI class may be need to update a window using this draw, so
#     384             # don't forget to call the superclass.
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      92     @wraps(draw)
#      93     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 94         result = draw(artist, renderer, *args, **kwargs)
#      95         if renderer._rasterizing:
#      96             renderer.stop_rasterizing()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      69                 renderer.start_filter()
#      70
# ---> 71             return draw(artist, renderer)
#      72         finally:
#      73             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    3255
#    3256                 self.patch.draw(renderer)
# -> 3257                 mimage._draw_list_compositing_images(
#    3258                     renderer, self, artists, self.suppressComposite)
#    3259
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     132     if not_composite or not has_images:
#     133         for a in artists:
# --> 134             a.draw(renderer)
#     135     else:
#     136         # Composite any adjacent images together
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      69                 renderer.start_filter()
#      70
# ---> 71             return draw(artist, renderer)
#      72         finally:
#      73             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_base.py in draw(self, renderer)
#    3143                 artists.remove(spine)
#    3144
# -> 3145         self._update_title_position(renderer)
#    3146
#    3147         if not self.axison:
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_base.py in _update_title_position(self, renderer)
#    3087             if title.get_text():
#    3088                 for ax in axs:
# -> 3089                     ax.yaxis.get_tightbbox(renderer)  # update offsetText
#    3090                     if ax.yaxis.offsetText.get_text():
#    3091                         bb = ax.yaxis.offsetText.get_tightbbox(renderer)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axis.py in get_tightbbox(self, renderer, for_layout_only)
#    1360         if renderer is None:
#    1361             renderer = self.get_figure(root=True)._get_renderer()
# -> 1362         ticks_to_draw = self._update_ticks()
#    1363
#    1364         self._update_label_position(renderer)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axis.py in _update_ticks(self)
#    1297             tick.label1.set_text(label)
#    1298             tick.label2.set_text(label)
# -> 1299         minor_locs = self.get_minorticklocs()
#    1300         minor_labels = self.minor.formatter.format_ticks(minor_locs)
#    1301         minor_ticks = self.get_minor_ticks(len(minor_locs))
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axis.py in get_minorticklocs(self)
#    1541         minor_locs = np.asarray(self.minor.locator())
#    1542         if self.remove_overlapping_locs:
# -> 1543             major_locs = self.major.locator()
#    1544             transform = self._scale.get_transform()
#    1545             tr_minor_locs = transform.transform(minor_locs)
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/ticker.py in __call__(self)
#    2226     def __call__(self):
#    2227         vmin, vmax = self.axis.get_view_interval()
# -> 2228         return self.tick_values(vmin, vmax)
#    2229
#    2230     def tick_values(self, vmin, vmax):
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/ticker.py in tick_values(self, vmin, vmax)
#    2234         vmin, vmax = mtransforms.nonsingular(
#    2235             vmin, vmax, expander=1e-13, tiny=1e-14)
# -> 2236         locs = self._raw_ticks(vmin, vmax)
#    2237
#    2238         prune = self._prune
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/ticker.py in _raw_ticks(self, vmin, vmax)
#    2164         if self._nbins == 'auto':
#    2165             if self.axis is not None:
# -> 2166                 nbins = np.clip(self.axis.get_tick_space(),
#    2167                                 max(1, self._min_n_ticks - 1), 9)
#    2168             else:
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axis.py in get_tick_space(self)
#    2821     def get_tick_space(self):
#    2822         ends = mtransforms.Bbox.unit().transformed(
# -> 2823             self.axes.transAxes - self.get_figure(root=False).dpi_scale_trans)
#    2824         length = ends.height * 72
#    2825         # Having a spacing of at least 2 just looks good.
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/transforms.py in __sub__(self, other)
#    1449             return NotImplemented
#    1450         for remainder, sub_tree in self._iter_break_from_left_to_right():
# -> 1451             if sub_tree == other:
#    1452                 return remainder
#    1453         for remainder, sub_tree in other._iter_break_from_left_to_right():
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/transforms.py in __eq__(self, other)
#    1777     def __eq__(self, other):
#    1778         if getattr(other, "is_affine", False) and hasattr(other, "get_matrix"):
# -> 1779             return (self.get_matrix() == other.get_matrix()).all()
#    1780         return NotImplemented
#    1781
#
# /usr/local/lib/python3.12/dist-packages/numpy/_core/_methods.py in _all(a, axis, dtype, out, keepdims, where)
#      65     return umr_any(a, axis, dtype, out, keepdims, where=where)
#      66
# ---> 67 def _all(a, axis=None, dtype=None, out=None, keepdims=False, *, where=True):
#      68     # By default, return a boolean for any and all
#      69     if dtype is None:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Design your own testing process and statistical analysis

# %%
from birdgame.model_benchmark.emwavartracker import EMWAVarTracker
from birdgame.trackers.tracker_evaluator import TrackerEvaluator
from birdgame.datasources.livedata import live_data_generator
from birdgame.datasources.remotetestdata import remote_test_data_generator
from birdgame.visualization.utils import get_loc_and_scale
from tqdm.auto import tqdm
import numpy as np

live = False
step_print = 1000
warmup_iterations = 300
max_iterations = 10000

tracker = EMWAVarTracker()
benchmark_tracker = EMWAVarTracker(horizon=tracker.horizon)

my_run, bmark_run = TrackerEvaluator(tracker), TrackerEvaluator(benchmark_tracker)
gen = live_data_generator() if live else remote_test_data_generator()

store_pred = []

try:
    for i, payload in enumerate(tqdm(gen, desc="Running Tracker")):
        my_run.tick_and_predict(payload)
        bmark_run.tick_and_predict(payload)

        # Only proceed if a valid prediction was made and scored
        if i > warmup_iterations and my_run.latest_valid_prediction is not None and len(my_run.scores) > 0:
            score = my_run.scores[-1]
            loc, scale = get_loc_and_scale(my_run.latest_valid_prediction)

            store_pred.append({
                "time": my_run.time,
                "prediction": my_run.latest_valid_prediction,
                "loc": loc,
                "scale": scale,
                "dove_location": my_run.dove_location,
                "score": score,
                "log_score": np.log(1e-10 + score)
            })

        if (i + 1) % step_print == 0:
            print(f"My likelihood score: {my_run.overall_likelihood_score():.4f} VS Benchmark likelihood score: {bmark_run.overall_likelihood_score():.4f}")

        if i > max_iterations:
            break

    print(f"My likelihood score: {my_run.overall_likelihood_score():.4f} VS Benchmark likelihood score: {bmark_run.overall_likelihood_score():.4f}")

except KeyboardInterrupt:
    print("Interrupted")
# Out:
# Running Tracker: 0it [00:00, ?it/s]
# My likelihood score: -11.0849 VS Benchmark likelihood score: -11.0849
# My likelihood score: -3.3915 VS Benchmark likelihood score: -3.3915
# My likelihood score: -2.8604 VS Benchmark likelihood score: -2.8604
# My likelihood score: -2.2542 VS Benchmark likelihood score: -2.2542
# My likelihood score: -1.7795 VS Benchmark likelihood score: -1.7795
# My likelihood score: -1.4862 VS Benchmark likelihood score: -1.4862
# My likelihood score: -1.2124 VS Benchmark likelihood score: -1.2124
# My likelihood score: -0.9781 VS Benchmark likelihood score: -0.9781
# My likelihood score: -0.7381 VS Benchmark likelihood score: -0.7381
# My likelihood score: -0.5376 VS Benchmark likelihood score: -0.5376
# My likelihood score: -0.5373 VS Benchmark likelihood score: -0.5373

# %%
from birdgame.visualization.utils import summarize_predictions
stats_summary, pred_summary = summarize_predictions(store_pred, skip_length=0)
# Out:
# Mean: {'score': 2.841, 'log_score': -0.537}
# Median: {'score': 2.799, 'log_score': 1.029}
# Std: {'score': 3.019, 'log_score': 4.418}
#
# Prediction Data:
#            time                                         prediction  \
# 0      93.00155  {'type': 'mixture', 'components': [{'density':...
# 1      93.00315  {'type': 'mixture', 'components': [{'density':...
# 2      93.00378  {'type': 'mixture', 'components': [{'density':...
# 3      93.03052  {'type': 'mixture', 'components': [{'density':...
# 4      93.04707  {'type': 'mixture', 'components': [{'density':...
# ...         ...                                                ...
# 9680  192.45907  {'type': 'mixture', 'components': [{'density':...
# 9681  192.46193  {'type': 'mixture', 'components': [{'density':...
# 9682  192.47212  {'type': 'mixture', 'components': [{'density':...
# 9683  192.50841  {'type': 'mixture', 'components': [{'density':...
# 9684  192.51382  {'type': 'mixture', 'components': [{'density':...
#
#              loc    scale  dove_location    score  log_score
# 0     2525.05902  0.00000     2525.00168  0.00000  -23.02585
# 1     2525.05902  0.00000     2525.00270  0.00000  -23.02585
# 2     2525.05902  0.00000     2525.00359  0.00000  -23.02585
# 3     2525.05902  0.00000     2525.00378  0.00000  -23.02585
# 4     2525.06781  0.00000     2525.00380  0.00000  -23.02585
# ...          ...      ...            ...      ...        ...
# 9680  2524.41795  0.09640     2524.35344  3.21616    1.16819
# 9681  2524.41795  0.09640     2524.36404  3.43630    1.23440
# 9682  2524.41751  0.09640     2524.37014  3.55871    1.26940
# 9683  2524.40318  0.09636     2524.36646  3.73250    1.31708
# 9684  2524.40318  0.09636     2524.36563  3.72039    1.31383
#
# [9685 rows x 7 columns]

# %% [markdown]
# #Diagnosing Model Behavior

# %%
from birdgame.visualization.viz_predictions import plot_dove_predictions
start_ind=8000
window_size=200
plot_dove_predictions(store_pred, start_ind, window_size)

# %% [markdown]
# #This notebook builds a threat-aware EWMA variance tracker using automated core-tail Gaussian mixtures for adaptive modeling. Developed for CrunchDAO’s market competition, it enables real-time uncertainty estimation and volatility-sensitive predictions.
